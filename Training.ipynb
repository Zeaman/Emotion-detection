# %% [markdown]
# ## Train the dataset (FER-2013)

# %% [markdown]
# ### Step-1: import the downloaded important libraries

# %%
import os
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPooling2D
from matplotlib import pyplot as plt
import numpy as np
import shutil
from google.colab import drive

# %% [markdown]
# ### Step-2: pre-process the dataset FER2013

# %%
drive.mount('/content/drive') # run this if you want to acces the dataset from driver
# Out:
# Mounted at /content/drive

# %%
# use this code for extracting the dataset.rar file in the Colab environemnt only
# !unrar x "/content/drive/MyDrive/dataset.rar" "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# craet the required directory
directory_FT = 'Facial_Tension'
directory_NFT = 'No_Facial_Tension'
parent_dir_test = '/content/dataset/test'
parent_dir_train = '/content/dataset/train'
path_test_FT = os.path.join(parent_dir_test, directory_FT)
path_test_NFT = os.path.join(parent_dir_test, directory_NFT)
path_train_FT = os.path.join(parent_dir_train, directory_FT)
path_train_NFT = os.path.join(parent_dir_train, directory_NFT)
os.mkdir(path_test_FT)
os.mkdir(path_test_NFT)
os.mkdir(path_train_FT)
os.mkdir(path_train_NFT)
print("Directory '% s' created for test Facial Tension" % directory_FT)
print("Directory '% s' created for test No Facial Tension" % directory_NFT)
print("Directory '% s' created for train Facial Tension" % directory_FT)
print("Directory '% s' created for train No Facial Tension" % directory_NFT)
# Out:
# Directory 'Facial_Tension' created for test Facial Tension
# Directory 'No_Facial_Tension' created for test No Facial Tension
# Directory 'Facial_Tension' created for train Facial Tension
# Directory 'No_Facial_Tension' created for train No Facial Tension

# %%
# move the catagorical images of the seven class to test dataset
target_dir_test_FT = '/content/dataset/test/Facial_Tension'
target_dir_test_NFT = '/content/dataset/test/No_Facial_Tension'  
source_dir_test_happy = '/content/dataset/test/happy' 
source_dir_test_neutral= '/content/dataset/test/neutral' 
source_dir_test_sad= '/content/dataset/test/sad'
source_dir_test_angry= '/content/dataset/test/angry'
source_dir_test_fear= '/content/dataset/test/fear'
source_dir_test_surprise= '/content/dataset/test/surprise'
source_dir_test_disgust= '/content/dataset/test/disgust'

allfiles_happy = os.listdir(source_dir_test_happy)
for f in allfiles_happy:
    src_path_happy = os.path.join(source_dir_test_happy, f)
    dst_path_happy = os.path.join(target_dir_test_NFT, f)
    shutil.move(src_path_happy, dst_path_happy)

allfiles_neutral= os.listdir(source_dir_test_neutral)
for f in allfiles_neutral:
    src_path_neutral = os.path.join(source_dir_test_neutral, f)
    dst_path_neutral = os.path.join(target_dir_test_NFT, f)
    shutil.move(src_path_neutral, dst_path_neutral)

allfiles_sad= os.listdir(source_dir_test_sad)
for f in allfiles_sad:
    src_path_sad = os.path.join(source_dir_test_sad, f)
    dst_path_sad = os.path.join(target_dir_test_FT, f)
    shutil.move(src_path_sad, dst_path_sad)

allfiles_angry= os.listdir(source_dir_test_angry)
for f in allfiles_angry:
    src_path_angry = os.path.join(source_dir_test_angry, f)
    dst_path_angry= os.path.join(target_dir_test_FT, f)
    shutil.move(src_path_angry, dst_path_angry)

allfiles_fear= os.listdir(source_dir_test_fear)
for f in allfiles_fear:
    src_path_fear = os.path.join(source_dir_test_fear, f)
    dst_path_fear= os.path.join(target_dir_test_FT, f)
    shutil.move(src_path_fear, dst_path_fear)

allfiles_surprise= os.listdir(source_dir_test_surprise)
for f in allfiles_surprise:
    src_path_surprise = os.path.join(source_dir_test_surprise, f)
    dst_path_surprise= os.path.join(target_dir_test_FT, f)
    shutil.move(src_path_surprise, dst_path_surprise)

allfiles_disgust= os.listdir(source_dir_test_disgust)
for f in allfiles_disgust:
    src_path_disgust = os.path.join(source_dir_test_disgust, f)
    dst_path_disgust= os.path.join(target_dir_test_FT, f)
    shutil.move(src_path_disgust, dst_path_disgust)

# %%
# Remove the folders that are empty inside the test directory
directory_test = "/content/dataset/test"   # You can change as per your dirctory of test
path_happy = os.path.join(directory_test, "happy")
os.rmdir(path_happy)
path_neutral = os.path.join(directory_test, "neutral")
os.rmdir(path_neutral)
path_sad = os.path.join(directory_test, "sad")
os.rmdir(path_sad)
path_fear = os.path.join(directory_test, "fear")
os.rmdir(path_fear)
path_angry = os.path.join(directory_test, "angry")
os.rmdir(path_angry)
path_surprise= os.path.join(directory_test, "surprise")
os.rmdir(path_surprise)
path_disgust = os.path.join(directory_test, "disgust")
os.rmdir(path_disgust)

# %%
# move the catagorical images of the seven class to train dataset
target_dir_train_FT = '/content/dataset/train/Facial_Tension'
target_dir_train_NFT = '/content/dataset/train/No_Facial_Tension'  
source_dir_train_happy = '/content/dataset/train/happy' 
source_dir_train_neutral= '/content/dataset/train/neutral' 
source_dir_train_sad= '/content/dataset/train/sad'
source_dir_train_angry= '/content/dataset/train/angry'
source_dir_train_fear= '/content/dataset/train/fear'
source_dir_train_surprise= '/content/dataset/train/surprise'
source_dir_train_disgust= '/content/dataset/train/disgust'

allfiles_happy = os.listdir(source_dir_train_happy)
for f in allfiles_happy:
    src_path_happy = os.path.join(source_dir_train_happy, f)
    dst_path_happy = os.path.join(target_dir_train_NFT, f)
    shutil.move(src_path_happy, dst_path_happy)

allfiles_neutral= os.listdir(source_dir_train_neutral)
for f in allfiles_neutral:
    src_path_neutral = os.path.join(source_dir_train_neutral, f)
    dst_path_neutral = os.path.join(target_dir_train_NFT, f)
    shutil.move(src_path_neutral, dst_path_neutral)

allfiles_sad= os.listdir(source_dir_train_sad)
for f in allfiles_sad:
    src_path_sad = os.path.join(source_dir_train_sad, f)
    dst_path_sad = os.path.join(target_dir_train_FT, f)
    shutil.move(src_path_sad, dst_path_sad)

allfiles_angry= os.listdir(source_dir_train_angry)
for f in allfiles_angry:
    src_path_angry = os.path.join(source_dir_train_angry, f)
    dst_path_angry= os.path.join(target_dir_train_FT, f)
    shutil.move(src_path_angry, dst_path_angry)

allfiles_fear= os.listdir(source_dir_train_fear)
for f in allfiles_fear:
    src_path_fear = os.path.join(source_dir_train_fear, f)
    dst_path_fear= os.path.join(target_dir_train_FT, f)
    shutil.move(src_path_fear, dst_path_fear)

allfiles_surprise= os.listdir(source_dir_train_surprise)
for f in allfiles_surprise:
    src_path_surprise = os.path.join(source_dir_train_surprise, f)
    dst_path_surprise= os.path.join(target_dir_train_FT, f)
    shutil.move(src_path_surprise, dst_path_surprise)

allfiles_disgust= os.listdir(source_dir_train_disgust)
for f in allfiles_disgust:
    src_path_disgust = os.path.join(source_dir_train_disgust, f)
    dst_path_disgust= os.path.join(target_dir_train_FT, f)
    shutil.move(src_path_disgust, dst_path_disgust)

# %%
# Remove the folders that are empty inside the train directory
directory_train = "/content/dataset/train"   # You can change as per your dirctory of train
path_happy = os.path.join(directory_train, "happy")
os.rmdir(path_happy)
path_neutral = os.path.join(directory_train, "neutral")
os.rmdir(path_neutral)
path_sad = os.path.join(directory_train, "sad")
os.rmdir(path_sad)
path_fear = os.path.join(directory_train, "fear")
os.rmdir(path_fear)
path_angry = os.path.join(directory_train, "angry")
os.rmdir(path_angry)
path_surprise= os.path.join(directory_train, "surprise")
os.rmdir(path_surprise)
path_disgust = os.path.join(directory_train, "disgust")
os.rmdir(path_disgust)

# %% [markdown]
# ### Step-3: Initialize image data generator with rescaling

# %%
IMG_HEIGHT=48 
IMG_WIDTH = 48
batch_size=512

train_data_dir='/content/dataset/train'
validation_data_dir='/content/dataset/test/'

validation_datagen = ImageDataGenerator(rescale=1./255)
# For test image dataset
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
fill_mode='nearest')  #48 is the pixcel of the image dataset with grayscale/CH-1

# %% [markdown]
# ### Step-4: Preprocess dataset images for test and train dataset

# %%
# For train image dataset
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    color_mode='grayscale',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)
# Out:
# Found 28708 images belonging to 2 classes.

# %%
# For test image dataset
validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    color_mode='grayscale',
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True)  #48 is the pixcel of the image dataset with grayscale/CH-1
# Out:
# Found 7178 images belonging to 2 classes.

# %%
#Verify our generator by plotting a few faces and printing corresponding labels
class_labels=['Facial Tension','No Facial Tension']

img, label = train_generator.__next__()

import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %% [markdown]
# ### Step-5: Construct the CNN model architecture

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(2, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())

# %% [markdown]
# ### Step-6: Train the model

# %%
train_path = "/content/dataset/train/"
test_path = "/content/dataset/test"

num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)


epochs=100

history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)

# %% [markdown]
# ### Step-7: Save the trained best model

# %%
# in json file format
model_json = model.to_json()
with open("emotion_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
# in .h5 format
model.save_weights('emotion_model.h5')

# %% [markdown]
# ### Step-8: Move the saved trained best model into best_model folder

# %%
#creat the directory
directory_model = 'best_model'
parent_dir_model = '/content'
path_model = os.path.join(parent_dir_model, directory_model)
os.mkdir(path_model)
print("Directory '% s' created for best_model" % directory_model)
# Out:
# Directory 'best_model' created for best_model

# %%
#move the saved json file into the above craeted directory
shutil.move('/content/emotion_model.json','/content/best_model')
# Out:
# '/content/best_model/emotion_model.json'

# %%
#move the saved .h5 file into the above craeted directory
shutil.move('/content/emotion_model.h5','/content/best_model')
# Out:
# '/content/best_model/emotion_model.h5'

# %% [markdown]
# ### Step-9:Test result evaluation by plotting the training results

# %%
history.history.keys()   #recored the data of the training using a function called history.history
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#plot the training loss in each epoch
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(0, 100)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#plot the training accuracy in each epoch
loss_train = history.history['accuracy']
loss_val = history.history['val_accuracy']
epochs = range(0, 100)
plt.plot(epochs, loss_train, 'g', label='Training accuracy')
plt.plot(epochs, loss_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
## Tnak you
