# %% [markdown]
# # Emotion detection using DL Downloading Required Dependency libraries

# %% [markdown]
# ### Step-1: install dependency libraries required for the project

# %%
# !pip install opencv-python
# !pip install matplotlib
# !pip install deepface
# !pip install numpy
# !pip install keras
# !pip install --upgrade tensorflow
# !pip install pillow
# !pip install scipy
# !pip install PyYAML
# !pip install astunparse
# !pip install shutil
# !pip install patool
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil
# ...
